# %% [markdown]
# # WNTR Demo: Earthquake Scenario

# %% [markdown]
# #### Import python packages, including WNTR

# %%
% matplotlib inline

import numpy as np
import pandas as pd
import pickle
import matplotlib.pylab as plt
from scipy.stats import expon
import wntr

np.random.seed(12345)
demo = False

# %% [markdown]
# #### Create a water network model using an EPANET inp file

# %%
inp_file = '../networks/Net6_skel16.inp'
wn = wntr.network.WaterNetworkModel(inp_file)
wn.scale_node_coordinates(200)
# Out:
# wntr.network.ParseWaterNetwork WARNING  WNTR only supports water quality analysis in the EpanetSimulator.
# WARNING:wntr.network.ParseWaterNetwork:WNTR only supports water quality analysis in the EpanetSimulator.
# wntr.network.ParseWaterNetwork WARNING  Currently, only the EpanetSimulator utilizes maximum levels for tanks. The other simulators do not place an upper limit on tank levels yet.
# WARNING:wntr.network.ParseWaterNetwork:Currently, only the EpanetSimulator utilizes maximum levels for tanks. The other simulators do not place an upper limit on tank levels yet.
# wntr.network.ParseWaterNetwork WARNING  Multiple demands per junction are currently only supported by the EpanetSimulator. Please check the [DEMANDS] section of your inp file.
# WARNING:wntr.network.ParseWaterNetwork:Multiple demands per junction are currently only supported by the EpanetSimulator. Please check the [DEMANDS] section of your inp file.
# wntr.network.ParseWaterNetwork WARNING  Energy analyses are currently only performed by the EpanetSimulator.
# WARNING:wntr.network.ParseWaterNetwork:Energy analyses are currently only performed by the EpanetSimulator.
# wntr.network.ParseWaterNetwork WARNING  Currently, only the EpanetSimulator supports the [REPORT] section of the inp file.
# WARNING:wntr.network.ParseWaterNetwork:Currently, only the EpanetSimulator supports the [REPORT] section of the inp file.

# %% [markdown]
# #### Define earthquake epicenter, magnitude, and depth

# %%
epicenter = (42000,22000) # x,y location
magnitude = 7 # Richter scale
depth = 10000 # m, shallow depth

# %% [markdown]
# #### Plot location of epicenter on the network

# %%
wntr.network.draw_graph(wn, node_size=0, figsize=(10,8), dpi=100)
plt.hold('True')
plt.scatter(epicenter[0], epicenter[1], s=1000, c='r', marker='*', zorder=2)

# %% [markdown]
# #### Generate the earthquake scenario

# %%
#This scenario assumes uniform pipe and soil type throughout the network.  These parameters can be set for individual pipes
#PGA = 0.001 g (0.01 m/s2) – perceptible by people
#PGA = 0.02  g (0.2  m/s2) – people lose their balance
#PGA = 0.50  g (5 m/s2) – very high; well-designed buildings can survive if the duration is short
#Repair rate of 1/km (0.001/m) has been suggested as an upper bound

earthquake = wntr.scenario.Earthquake(epicenter, magnitude, depth)

R = earthquake.distance_to_epicenter(wn, element_type=wntr.network.Pipe)
pga = earthquake.pga_attenuation_model(R)  
pgv = earthquake.pgv_attenuation_model(R)
RR = earthquake.repair_rate_model(pgv)
L = pd.Series(wn.query_link_attribute('length', link_type = wntr.network.Pipe))
    
pipe_FC = wntr.scenario.FragilityCurve()
pipe_FC.add_state('Minor leak', 1, {'Default': expon(scale=0.2)})
pipe_FC.add_state('Major leak', 2, {'Default': expon()})

plt.figure()
x = np.linspace(0,1,100)
for name, state in pipe_FC.states():
    dist=state.distribution['Default']
    plt.plot(x,dist.cdf(x), label=name)
plt.ylim((0,1))
plt.xlabel('Rate of repair * pipe length')
plt.ylabel('Probability of exceeding a damage state')
plt.legend()

pipe_Pr = pipe_FC.cdf_probability(RR*L)
pipe_damage_state = pipe_FC.sample_damage_state(pipe_Pr)

pipe_damage_state_map = pipe_FC.get_priority_map()
pipe_damage_val = pipe_damage_state.map(pipe_damage_state_map)

print "Min, Max, Average PGA: " + str(np.round(pga.min(),2)) + ", " + str(np.round(pga.max(),2)) + ", " + str(np.round(pga.mean(),2)) + " g"
print "Min, Max, Average PGV: " + str(np.round(pgv.min(),2)) + ", " + str(np.round(pgv.max(),2)) + ", " + str(np.round(pgv.mean(),2)) + " m/s"
print "Min, Max, Average repair rate: " + str(np.round(RR.min(),5)) + ", " + str(np.round(RR.max(),5)) + ", " + str(np.round(RR.mean(),5)) + " per m"
print "Min, Max, Average repair rate*pipe length: " + str(np.round((RR*L).min(),5)) + ", " + str(np.round((RR*L).max(),5)) + ", " + str(np.round((RR*L).mean(),5))
print "Number of pipe failures: " + str(sum(pipe_damage_val > 0))
# Out:
# Min, Max, Average PGA: 0.14, 0.45, 0.26 g
# Min, Max, Average PGV: 0.24, 1.42, 0.6 m/s
# Min, Max, Average repair rate: 6e-05, 0.00034, 0.00015 per m
# Min, Max, Average repair rate*pipe length: 3e-05, 0.7647, 0.04661
# Number of pipe failures: 261

# %% [markdown]
# #### Plot peak ground acceleration

# %%
wntr.network.draw_graph(wn, link_attribute=R, node_size=20, title='Distance to Epicenter', figsize=(12,8), dpi=100)

wntr.network.draw_graph(wn, link_attribute=pga, node_size=0, link_width=1.5, title='Peak ground acceleration', figsize=(12,8), dpi=100)

wntr.network.draw_graph(wn, link_attribute=pgv, node_size=0, link_width=1.5, title='Peak ground velocity', figsize=(12,8), dpi=100)
# Out:
# (<matplotlib.collections.PathCollection at 0x1a1b0610>,
#  <matplotlib.collections.LineCollection at 0x1a1f3f90>)

# %% [markdown]
# #### Plot repair rate (# of repairs needed per m)

# %%
wntr.network.draw_graph(wn, link_attribute=RR, node_size=0, link_width=1.5, title='Repair rate', figsize=(12,8), dpi=100)

wntr.network.draw_graph(wn, link_attribute=(RR*L), node_size=0, link_width=1.5, title='Repair rate*Pipe length', figsize=(12,8), dpi=100)
# Out:
# (<matplotlib.collections.PathCollection at 0x1a650650>,
#  <matplotlib.collections.LineCollection at 0x1a245ad0>)

# %% [markdown]
# #### Plot location of pipes with leaks

# %%
wntr.network.draw_graph(wn, link_attribute=pipe_Pr['Minor leak'], node_size=0, link_width=1.5, title='Probability of pipe failure', figsize=(12,8), dpi=100)

gray_red_colormap = wntr.network.custom_colormap(2, colors = ['0.75','red'])
wntr.network.draw_graph(wn, link_attribute=pipe_damage_val, node_size=0, link_width=1.5, link_cmap=gray_red_colormap, link_range=[0,1], title='Failed pipes (in red)', add_colorbar=False, figsize=(10,8), dpi=100)
# Out:
# (<matplotlib.collections.PathCollection at 0x1a5545f0>,
#  <matplotlib.collections.LineCollection at 0x1a309e30>)

# %% [markdown]
# #### Add leaks to the model and simulate hydraulics

# %%
# The simulation uses pressure driven hydraulics and leak models to account for loss.
for name, node in wn.nodes():
    node.nominal_pressure = 15
wn.options.duration = 24*3600
wn.options.hydraulic_timestep = 3600
wn.options.report_timestep = 3600

time_of_failure = 5 # time of failure
duration_of_failure = 20 # Select duration of failure  
for pipe_name, damage_state in pipe_damage_state.iteritems():
    if damage_state is not None:
        # Select leak diameter, uniform dist, between 0.01 and pipe diameter 
        pipe_diameter = wn.get_link(pipe_name).diameter
        leak_diameter = np.round(np.random.uniform(0.01,0.2*pipe_diameter,1), 2)[0] 
        leak_area = 3.14159/4.0*leak_diameter**2
        # Add pipe leak to the network
        wn.split_pipe_with_junction(pipe_name,pipe_name+'A',pipe_name+'B','Leak'+pipe_name)
        n = wn.get_node('Leak'+pipe_name)
        n.add_leak(area=leak_area)
        # Add time control
        start_time = time_of_failure*3600
        end_time = (time_of_failure+duration_of_failure)*3600
        active_control_action = wntr.network.TargetAttributeControlAction(n, 'leak_status', True)
        inactive_control_action = wntr.network.TargetAttributeControlAction(n, 'leak_status', False)
        control = wntr.network.TimeControl(wn, start_time, 'SIM_TIME', False, active_control_action)
        wn.add_control(control)
        control = wntr.network.TimeControl(wn, end_time, 'SIM_TIME', False, inactive_control_action)
        wn.add_control(control)

sim = wntr.sim.ScipySimulator(wn, pressure_driven=True)

if demo:
    results = pickle.load(open('demo_Net6.pickle', 'rb'))
else:
    results = sim.run_sim()
    pickle.dump(results, open('demo_Net6.pickle', 'wb'))
# Out:
# simulation time =  0:0:0 , trial =  0
# simulation time =
#  0:0:0 , trial =  1
# simulation time =
#  0:0:2 , trial =  0
# simulation time =
#  0:30:36 , trial =  0
# simulation time =
#  0:32:31 , trial =  0
# simulation time =
#  0:40:6 , trial =  0
# simulation time =
#  0:42:31 , trial =  0
# simulation time =
#  0:42:50 , trial =  0
# simulation time =
#  0:46:43 , trial =  0
# simulation time =
#  0:49:22 , trial =  0
# simulation time =
#  0:49:38 , trial =  0
# simulation time =
#  0:53:46 , trial =  0
# simulation time =
#  0:56:59 , trial =  0
# simulation time =
#  1:0:0 , trial =  0
# simulation time =
#  1:16:30 , trial =  0
# We have  10  isolated junctions.
# We have  11  isolated links.
# simulation time =
#  1:16:30 , trial =  1
# simulation time =
#  1:16:30 , trial =  2
# simulation time =
#  1:24:55 , trial =  0
# simulation time =
#  1:24:55 , trial =  1
# simulation time =
#  1:30:13 , trial =  0
# simulation time =
#  1:36:30 , trial =  0
# simulation time =
#  1:42:3 , trial =  0
# simulation time =
#  2:0:0 , trial =  0
# simulation time =
#  2:16:6 , trial =  0
# simulation time =
#  2:30:45 , trial =  0
# simulation time =
#  2:40:28 , trial =  0
# simulation time =
#  2:41:41 , trial =  0
# simulation time =
#  3:0:0 , trial =  0
# simulation time =
#  3:0:3 , trial =  0
# simulation time =
#  3:11:53 , trial =  0
# simulation time =
#  3:42:12 , trial =  0
# We have  10  isolated junctions.
# We have  11  isolated links.
# simulation time =
#  3:42:12 , trial =  1
# simulation time =
#  3:42:12 , trial =  2
# simulation time =
#  3:51:29 , trial =  0
# simulation time =
#  3:55:48 , trial =  0
# simulation time =
#  3:55:48 , trial =  1
# simulation time =
#  3:55:48 , trial =  2
# simulation time =
#  4:0:0 , trial =  0
# simulation time =
#  4:11:31 , trial =  0
# simulation time =
#  4:29:18 , trial =  0
# simulation time =
#  4:45:2 , trial =  0
# simulation time =
#  4:45:19 , trial =  0
# simulation time =
#  4:58:54 , trial =  0
# simulation time =
#  4:58:54 , trial =  1
# simulation time =
#  5:0:0 , trial =  0
# simulation time =
#  5:0:16 , trial =  0
# simulation time =
#  5:5:42 , trial =  0
# simulation time =
#  5:9:3 , trial =  0
# simulation time =
#  5:10:30 , trial =  0
# simulation time =
#  5:11:11 , trial =  0
# simulation time =
#  5:25:41 , trial =  0
# simulation time =
#  5:27:39 , trial =  0
# simulation time =
#  5:30:14 , trial =  0
# simulation time =
#  5:31:17 , trial =  0
# simulation time =
#  5:31:21 , trial =  0
# simulation time =
#  5:40:25 , trial =  0
# simulation time =
#  5:40:42 , trial =  0
# simulation time =
#  5:56:32 , trial =  0
# residual for headloss equation for link
#  PUMP-3840  is  176.055117642 ; flow =  1.43273892866
# residual for headloss equation for link  PUMP-3839  is  176.055117642 ; flow =  1.43273892866
# c:\kaklise\epa-resilience\resilience\wntr\sim\ScipyModel.py:1205: UserWarning: Pump smoothing polynomial is not monotonically decreasing.
#   warnings.warn('Pump smoothing polynomial is not monotonically decreasing.')
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-29-ca0408625640> in <module>()
#      33     results = pickle.load(open('demo_Net6.pickle', 'rb'))
#      34 else:
# ---> 35     results = sim.run_sim()
#      36     pickle.dump(results, open('demo_Net6.pickle', 'wb'))
#
# c:\kaklise\epa-resilience\resilience\wntr\sim\ScipySimulator.pyc in run_sim(self)
#     111             if solver_status == 0:
#     112                 model.check_infeasibility(self._X)
# --> 113                 raise RuntimeError('No solution found.')
#     114             X_init = copy.copy(self._X)
#     115
#
# RuntimeError: No solution found.

# %% [markdown]
# #### Define top leaks for repair

# %%
# Plot leak demand
plt.figure(figsize=(12,5), dpi=100)
leaked_demand = results.node.loc['leak_demand']
leaked_demand.plot(ax=plt.gca(), legend=False)
plt.ylabel('Leak demand (m3/s)')

# Rank leaked demand
leaked_sum = leaked_demand.sum()
leaked_sum.sort(ascending=False, inplace=True)

# Select top 20
pipes_to_fix = leaked_sum[0:20]
print pipes_to_fix

# %% [markdown]
# #### Simulate hydraulics with repair

# %%
duration_of_failure = 10
for leak_name in pipes_to_fix.index:
    leak = wn.get_node(leak_name)
    leak.leak_end_time=(time_of_failure+duration_of_failure)*3600

sim = wntr.sim.ScipySimulator(wn, pressure_driven=True)

if demo:
    results_repair = pickle.load(open('demo_Net6_repair.pickle', 'rb'))
else:
    results_repair = sim.run_sim()
    pickle.dump(results_repair, open('demo_Net6_repair.pickle', 'wb'))

# %% [markdown]
# #### Compare results

# %%
wn_nodes = [node_name for node_name, node in wn.nodes(wntr.network.Junction)]

pressure_at_24hr = results.node.loc['pressure',24*3600,wn_nodes]
wntr.network.draw_graph(wn, node_attribute=pressure_at_24hr, node_size=20, node_range = [0,90], title='Pressure at 24 hours, without repair', figsize=(12,8), dpi=100)

pressure_at_24hr = results_repair.node.loc['pressure',24*3600,wn_nodes]
wntr.network.draw_graph(wn, node_attribute=pressure_at_24hr, node_size=20, node_range = [0,90], title='Pressure at 24 hours, with repair', figsize=(12,8), dpi=100)

# Node pressure
plt.figure(figsize=(30,8), dpi=100)
plt.subplot(1,2,1)
for name, node in wn.nodes(wntr.network.Junction):
    pressure = results.node['pressure',:,name] 
    pressure.plot()
    plt.hold(True)
plt.ylim(ymin=0)
plt.ylabel('Node Pressure (m)')
plt.title('Without repair')

plt.subplot(1,2,2)
for name, node in wn.nodes(wntr.network.Junction):
    pressure = results_repair.node['pressure',:,name] 
    pressure.plot()
    plt.hold(True)
plt.ylim(ymin=0)
plt.ylabel('Node Pressure (m)')
plt.title('With repair')

# Tank pressure
plt.figure(figsize=(30,8), dpi=100)
plt.subplot(1,2,1)
for name, tank in wn.nodes(wntr.network.Tank):
    pressure = results.node['pressure',:,name]
    pressure.plot(label=name)
    plt.hold(True)
plt.ylim(ymin=0, ymax=12)
plt.ylabel('Tank Pressure (m)')
#plt.legend()

plt.subplot(1,2,2)
for name, tank in wn.nodes(wntr.network.Tank):
    pressure = results_repair.node['pressure',:,name]
    pressure.plot(label=name)
    plt.hold(True)
plt.ylim(ymin=0, ymax=12)
plt.ylabel('Tank Pressure (m)')
#plt.legend()

# Fraction delivered volume
nzd_junctions = wn.query_node_attribute('base_demand', np.greater, 0, node_type=wntr.network.Junction).keys()  
node_results = results.node.loc[:,:,nzd_junctions]
node_results_repair = results_repair.node.loc[:,:,nzd_junctions]

plt.figure(figsize=(30,8), dpi=100)
plt.subplot(1,2,1)
FDV_knt = wntr.metrics.fdv(node_results) # FDV, scenario k, node n, time t 
FDV_knt.plot(ax=plt.gca(), legend=False)
plt.ylim(ymin=-0.05, ymax=1.05)
plt.ylabel('FDV')

plt.subplot(1,2,2)
FDV_knt = wntr.metrics.fdv(node_results_repair) # FDV, scenario k, node n, time t 
FDV_knt.plot(ax=plt.gca(), legend=False)
plt.ylim(ymin=-0.05, ymax=1.05)
plt.ylabel('FDV')

plt.figure(figsize=(30,8), dpi=100)
plt.subplot(1,2,1)
FDV_kt = wntr.metrics.fdv(node_results, average_nodes=True) # FDV, scenario k, time t
FDV_kt.plot(label='Average', color='k', linewidth=3.0, legend=False)
plt.ylim(ymin=-0.05, ymax=1.05)
plt.ylabel('Average FDV')

plt.subplot(1,2,2)
FDV_kt = wntr.metrics.fdv(node_results_repair, average_nodes=True) # FDV, scenario k, time t
FDV_kt.plot(label='Average', color='k', linewidth=3.0, legend=False)
plt.ylim(ymin=-0.05, ymax=1.05)
plt.ylabel('Averaege FDV')
